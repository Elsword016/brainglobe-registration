# %%
from brainglobe_atlasapi import BrainGlobeAtlas
from skimage.io import *

#from brainglobe_registration.grid_search import *

#from brainglobe_registration.simple_grid_search import* 
from brainglobe_registration.similarity_metrics import *

# %%
moving_img = imread(r'D:\portfolio\brainglobe-registration\tests\test_images\sample_hipp.tif')
print(moving_img.shape)
# Out:
# (318, 428)

# %%
atlas = BrainGlobeAtlas('allen_mouse_100um')
print(atlas.reference.shape)
# Out:
# c:\Users\BiswanathSaha\miniconda3\envs\brainglobe\Lib\site-packages\rich\live.py:231: UserWarning: install
# "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 atlas = BrainGlobeAtlas('allen_mouse_100um')
#       2 print(atlas.reference.shape)
#
# File c:\Users\BiswanathSaha\miniconda3\envs\brainglobe\Lib\site-packages\brainglobe_atlasapi\bg_atlas.py:93, in BrainGlobeAtlas.__init__(self, atlas_name, brainglobe_dir, interm_download_dir, check_latest, config_dir, fn_update)
#      91         raise ValueError(f"{atlas_name} is not a valid atlas name!")
#      92     else:
# ---> 93         self.download_extract_file()
# ...

# %%
best_slice, similarity, results = run_grid_search(
    moving_img,
    atlas.reference,
    mode="slice_only",
    metric="ssim",
    visualize=True
)

# %%
best_slice, similarity, results = run_grid_search(
    moving_img,
    atlas.reference,
    mode="multi_param",
    metric="ssim",
    visualize=True
)

# %%
best_params, similarity, results = run_grid_search(
    moving_img,
    atlas.reference,
    mode="multi_param",
    slice_range=(100,atlas.reference.shape[0]),
    slice_step=2,
    x_translations=[-10, -5, 0, 5, 10],
    y_translations=[-10, -5, 0, 5, 10],
    rotation_angles=[-10, -5, 0, 5, 10],
    metric="ncc"
)

# %%
# Visualize results
visualize_multiparameter_results(
    result_dict,
    atlas.reference,
    moving_img,
    best_params,
    save_path=None 
)

# %%
# Visualize results
visualize_multiparameter_results(
    result_dict,
    atlas.reference,
    moving_img,
    best_params,
    save_path=None 
)
